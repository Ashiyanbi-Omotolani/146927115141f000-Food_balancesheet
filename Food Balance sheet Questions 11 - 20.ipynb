# %%
import numpy as np
import pandas as pd
food_balancesheet_data=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="ISO-8859-1")
food_balancesheet_data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
 #using pandas describe function to get a summary of the dataset.

import numpy as np
import pandas as pd
food_balancesheet_data=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="ISO-8859-1")
food_balancesheet_data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
# Checking for missing values

import numpy as np
import pandas as pd
food_balancesheet_data=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="ISO-8859-1")
food_balancesheet_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
# Filling the missing values in column fuel unit with the most common value(0.000000)

import numpy as np
import pandas as pd
food_balancesheet_data=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="ISO-8859-1")
food_balancesheet_data.fillna(0.000000)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# Question 11A :- What is the total sum of Animal Fat produced in Y2014 (perform a groupby sum aggregation on ‘item’)
# Answer 11A:-  Animal fats(Y2014)   209460.54

Item_sum=food_balancesheet_data.groupby(['Item'])['Y2014'].sum()
print(Item_sum)
# Out:
# Item
# Alcohol, Non-Food        2403.00
# Alcoholic Beverages    102410.11
# Animal Products         11935.65
# Animal fats            209460.54
# Apples and products      9499.23
#                          ...
# Vegetables, Other      155038.96
# Vegetal Products       107145.19
# Wheat and products     232670.13
# Wine                     4497.36
# Yams                   200396.96
# Name: Y2014, Length: 119, dtype: float64

# %%
# Question 11b :- What is the total sum of Animal Fat produced in Y2017 (perform a groupby sum aggregation on ‘item’)
# Answer 11A:-  Animal fats(Y2017) 269617.53
Item_sum=food_balancesheet_data.groupby(['Item'])['Y2017'].sum()
print(Item_sum)
# Out:
# Item
# Alcohol, Non-Food        2348.00
# Alcoholic Beverages     95581.06
# Animal Products         11547.65
# Animal fats            269617.53
# Apples and products     10198.90
#                          ...
# Vegetables, Other      157752.59
# Vegetal Products       107655.20
# Wheat and products     240047.62
# Wine                     4178.02
# Yams                   229174.59
# Name: Y2017, Length: 119, dtype: float64

# %%
# Question 12:- What is the mean and standard deviation across the dataset for year 2015 to 3 decimal places?
# Answer:- #using pandas describe function to get a summary of the dataset. 135.236 and 1603.40

import numpy as np
import pandas as pd
food_balancesheet_data=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="ISO-8859-1")
food_balancesheet_data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
# QUESTION 13:- What is the total number of missing data in 2016 to 2 decimal places?
# ANSWER:- Y2016           1535 and 2.58/2.52
# Checking for missing values

import numpy as np
import pandas as pd
food_balancesheet_data=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="ISO-8859-1")
food_balancesheet_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
# Question 13b percent in 2016 to 2 decimal places?

percentage = 100 * 1535/59408
print(percentage)
# Out:
# 2.583827093994075

# %%
# QUESTION 14:- Which year had the highest correlation with ‘Element Code’?
# Answer:- Y2014 = 0.024457

import pandas as pd
food_balancesheet_data=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="ISO-8859-1")  
food_balancesheet_data.corr(method ='pearson')
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
# Question 15a:- Which year has the highest sum of Import Quantity for Y2014? (Perform a groupby on 'Element' and use the DataFrame to answer the question)
# Answer:-  Import Quantity=274144.48
Element_sum=food_balancesheet_data.groupby(['Element'])['Y2014'].sum()
print(Element_sum)
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %%
# Question 15b:- Which year has the highest sum of Import Quantity for Y2015? (Perform a groupby on 'Element' and use the DataFrame to answer the question)
# Answer:-  Import Quantity=267018.46
Element_sum=food_balancesheet_data.groupby(['Element'])['Y2015'].sum()
print(Element_sum)
# Out:
# Element
# Domestic supply quantity                  2021493.55
# Export Quantity                            157614.47
# Fat supply quantity (g/capita/day)          10235.74
# Feed                                       225050.22
# Food                                      1232361.10
# Food supply (kcal/capita/day)              453383.00
# Food supply quantity (kg/capita/yr)         49345.13
# Import Quantity                            267018.46
# Losses                                     155439.00
# Other uses (non-food)                       66254.41
# Processing                                 287929.00
# Production                                1947019.39
# Protein supply quantity (g/capita/day)      11833.95
# Residuals                                   30045.00
# Seed                                        23976.82
# Stock Variation                             34910.99
# Total Population - Both sexes             1058081.00
# Tourist consumption                           349.00
# ...

# %%
# Question 15c:- Which year has the highest sum of Import Quantity for Y2016? (Perform a groupby on 'Element' and use the DataFrame to answer the question)
# Answer:-  Import Quantity=286582.78
Element_sum=food_balancesheet_data.groupby(['Element'])['Y2016'].sum()
print(Element_sum)
# Out:
# Element
# Domestic supply quantity                  2044842.70
# Export Quantity                            151920.46
# Fat supply quantity (g/capita/day)          10102.77
# Feed                                       228958.65
# Food                                      1247022.17
# Food supply (kcal/capita/day)              451810.00
# Food supply quantity (kg/capita/yr)         48985.28
# Import Quantity                            286582.78
# Losses                                     157787.00
# Other uses (non-food)                       69563.68
# Processing                                 280631.00
# Production                                1943537.15
# Protein supply quantity (g/capita/day)      11779.69
# Residuals                                   37224.00
# Seed                                        23389.20
# Stock Variation                             33140.12
# Total Population - Both sexes             1085107.00
# Tourist consumption                            89.00
# ...

# %%
# Question 15d:- Which year has the highest sum of Import Quantity for Y2017? (Perform a groupby on 'Element' and use the DataFrame to answer the question)
# Answer:-  Import Quantity=294559.09 
# Final Answer:- Y2017 has the sum of import quantity
Element_sum=food_balancesheet_data.groupby(['Element'])['Y2017'].sum()
print(Element_sum)
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
# Question 15e:- Which year has the highest sum of Import Quantity for Y2018? (Perform a groupby on 'Element' and use the DataFrame to answer the question)
# Answer:-  Import Quantity=287997.09
Element_sum=food_balancesheet_data.groupby(['Element'])['Y2018'].sum()
print(Element_sum)
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
# Question 16:- What is the Total sum of Production in Y2014? (Perform a groupby on 'Element' and use the DataFrame to answer the question)
# Answer:-  Production = 1931287.75
Element_sum=food_balancesheet_data.groupby(['Element'])['Y2014'].sum()
print(Element_sum)
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %%
# Question 17:- Which of these Elements had the highest sum in 2018?(Select column 'Y2018' and 'Element',Perform a groupby on 'Element' and use the DataFrame to answer the question)
# Answer:- Domestic supply quantity = 2,161,192.10
Element_sum=food_balancesheet_data.groupby(['Element'])['Y2018'].sum()
print(Element_sum)
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
# Question 18:- Which of these Elements had the third lowest sum in 2018?(Select column 'Y2018' and 'Element',Perform a groupby on 'Element' and use the DataFrame to answer the question)
# Answer:- Protein supply quantity (g/capita/day) = 11833.56
Element_sum=food_balancesheet_data.groupby(['Element'])['Y2018'].sum()
print(Element_sum)
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
# Question 19:- What is the Total Import Quantity in Algeria in Y2018?

Area_sum=food_balancesheet_data.groupby(['Area','Element'])['Y2018'].sum()
print(Area_sum)
# Out:
# Area      Element
# Algeria   Domestic supply quantity                  90023.42
#           Export Quantity                             811.54
#           Fat supply quantity (g/capita/day)          309.09
#           Feed                                      10668.00
#           Food                                      63736.33
#                                                       ...
# Zimbabwe  Protein supply quantity (g/capita/day)      176.57
#           Residuals                                  -546.00
#           Seed                                        140.00
#           Stock Variation                            -447.00
#           Total Population - Both sexes             14439.00
# Name: Y2018, Length: 803, dtype: float64

# %%
# Question 19:- What is the Total Import Quantity in Algeria in Y2018?
food_balancesheet_data.loc[food_balancesheet_data['Element'].isin(['Element','Import Quantity'])]['Area'].count()
# Out:
# 5139

# %%
Element_sum=food_balancesheet_data.groupby(['Element', 'Area'])['Y2018'].sum()
print(Element_sum)
# Out:
# Element                   Area
# Domestic supply quantity  Algeria                  90023.42
#                           Angola                   59590.22
#                           Benin                    31447.90
#                           Botswana                  3045.85
#                           Burkina Faso             25705.16
#                                                      ...
# Tourist consumption       Cabo Verde                   7.00
#                           Egypt                       23.00
#                           Kenya                       17.00
#                           Mauritius                   31.00
#                           Sao Tome and Principe       12.00
# Name: Y2018, Length: 803, dtype: float64

# %%
# Question 20:- What is the total number of unique countires in the dataset?
food_balancesheet_data.Area.nunique()
# Out:
# 49

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
food_balancesheet_data=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="ISO-8859-1")
food_balancesheet_data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
food_balancesheet_data.tail()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 60938                                    Food      1000 tonnes  42.00  46.00
# 60939     Food supply quantity (kg/capita/yr)               kg   3.06   3.33
# 60940           Food supply (kcal/capita/day)  kcal/capita/day   3.00   4.00
# 60941  Protein supply quantity (g/capita/day)     g/capita/day   0.10   0.11
# 60942      Fat supply quantity (g/capita/day)     g/capita/day   0.04   0.05
#
#        Y2016  Y2017  Y2018
# 60938  33.00  19.00  16.00
# 60939   2.35   1.33   1.08
# ...

# %%
food_balancesheet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
# food_balancesheet_data corr()

food_balancesheet_data.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
food_balancesheet_data.groupby(['Y2014','Y2017']).sum()
# Out:
#                      Area Code  Item Code  Element Code     Y2015     Y2016  \
# Y2014     Y2017
# -1796.0    0.0             159       2657          5072     -73.0     -12.0
# -1631.0   -689.0           159       2924          5072       6.0     -77.0
# -849.0    -600.0           266       5444         10340   -1118.0   -1119.0
# -838.0    -538.0           184       2907          5072    -827.0    -679.0
# -685.0     689.0           143       2905          5072    3418.0   -3225.0
# ...                        ...        ...           ...       ...       ...
#  90425.0   96443.0          59       2501           511   92443.0   94447.0
#  98094.0   106400.0        238       2501           511  100835.0  103603.0
#  108756.0  112625.0        159       2907          5301  110798.0  116483.0
#  109593.0  117702.0        159       2907          5511  111663.0  119330.0
#  176405.0  190873.0        159       2501           511  181137.0  185960.0
#
#                         Y2018
# ...

# %%
# Question 15
print(np.mean(food_balancesheet_data['Y2015']))
print(np.std(food_balancesheet_data['Y2015']))
# Out:
# 135.23596649549236
# 1603.3904860828056

# %%
food_balancesheet_data[['Y2018','Element']].groupby(['Element']).sum()
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...
